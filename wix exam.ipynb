# %% [markdown]
# # WIX EXAM
#
#
# ## Q4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Book1.csv')

# %%
data[0:3]
# Out:
#   money youtube facebook pinterest
# 1  1000     200      100       150
# 2  2000     260      190       250
# 3  3000     317      275       330

# %%
data = data.rename(columns={'Unnamed: 0':'money', 'Unnamed: 1': 'youtube', 'Unnamed: 2': 'facebook', 'Unnamed: 3':'pinterest'})

# %%
data = data.drop([0])

# %%
data['youtube']=pd.to_numeric(data['youtube'])
data['facebook']=pd.to_numeric(data['facebook'])
data['pinterest']=pd.to_numeric(data['pinterest'])

# %%
possible1 =[]
for y in range(1,18):
    for f in range(1,20-y):
        for p in range(1,20-y-f):
            score = data['youtube'][y]+data['facebook'][f]+data['pinterest'][p]
            possible.append(score)
            if possible:     
                if score >= max(possible):
                    indexs= [y,f,p]

plt.plot(possible)

# %%
max(possible )
# Out:
# 1548

# %% [markdown]
# ### the answer to part a :
# ### youtube-5000
# ### facebook-9000
# ### pinterest- 5000

# %%
indexs
# Out:
# [5, 9, 5]

# %%
possible2 =[]
for y in range(1,18):
    for f in range(1,20-y):
        for p in range(1,20-y-f):
            score = data['youtube'][y]+data['facebook'][f]+data['pinterest'][p]
            final_s = score*15 - (y+f+p)*1000
            possible2.append(final_s)
            if possible2:     
                if final_s >= max(possible2):
                    indexs2= [y,f,p]

plt.plot(possible2)

# %% [markdown]
# ### the answer to part b :
# ### youtube-1000
# ### facebook-6000
# ### pinterest- 3000

# %%
indexs2
# Out:
# [1, 6, 3]

# %% [markdown]
# # Q 3

# %%
data2 = pd.read_csv('Book2.csv')

# %%
data2
# Out:
#           Date Day of Week            Browser Country Code User Category  \
# 0     1/1/2015    Thursday             Chrome           BR  online-store
# 1     1/1/2015    Thursday             Chrome           BR  online-store
# 2     1/1/2015    Thursday             Chrome           RU  online-store
# 3     1/1/2015    Thursday             Chrome           US  hotel-travel
# 4     1/1/2015    Thursday            Firefox           GB         other
# ...        ...         ...                ...          ...           ...
# 9606  2/5/2015    Thursday  Internet Explorer           US   photography
# 9607  2/5/2015    Thursday              Opera           GB  online-store
# 9608  2/5/2015    Thursday             Safari           AU         other
# 9609  2/5/2015    Thursday             Safari           RU  online-store
# 9610  2/5/2015    Thursday             Safari           RU         other
#
#      Operating System  Registrations  Sites Created  Sales  Unnamed: 9  \
# ...

# %%
data2['Date'] = pd.to_datetime(data2['Date'])

# %%
data2 = data2.drop(columns=['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'])

# %%
japan_data = data2[data2['Country Code'] == 'JP']
japan_data
# Out:
#            Date Day of Week            Browser Country Code User Category  \
# 16   2015-01-01    Thursday             Safari           JP  online-store
# 28   2015-01-01    Thursday              Opera           JP         other
# 36   2015-01-01    Thursday             Chrome           JP  hotel-travel
# 37   2015-01-01    Thursday             Chrome           JP   photography
# 40   2015-01-01    Thursday            Firefox           JP   photography
# ...         ...         ...                ...          ...           ...
# 9557 2015-02-05    Thursday             Safari           JP  online-store
# 9575 2015-02-05    Thursday             Chrome           JP         other
# 9593 2015-02-05    Thursday             Safari           JP  online-store
# 9596 2015-02-05    Thursday             Chrome           JP   photography
# 9604 2015-02-05    Thursday  Internet Explorer           JP  online-store
#
#      Operating System  Registrations  Sites Created  Sales
# ...

# %% [markdown]
# ## Japanese  Sales

# %%
a = plt.axes()
a.plot(japan_data['Date'], japan_data['Sales'])
a.xaxis.set_major_locator(plt.MaxNLocator(5))

# %% [markdown]
# ## Global Campaign

# %%
b = plt.axes()
b.plot(data2['Date'],data2['Registrations'])
b.xaxis.set_major_locator(plt.MaxNLocator(5))

# %%
c = plt.axes()
c.plot(data2['Date'],data2['Sites Created'])
c.xaxis.set_major_locator(plt.MaxNLocator(5))

# %% [markdown]
# # Q2

# %%
data3 = pd.read_csv('Book3.csv')

# %%
data3
# Out:
#    United States       Costs  Visits  Registrations  Sites Created  Sales  \
# 0          1-May  $14,375.00  20,338          5,055          1,650  1,007
# 1          2-May  $14,068.00  20,063          4,822          1,615    986
# 2          3-May  $14,493.00  20,477          4,938          1,656  1,008
# 3          4-May  $15,494.00  22,229          5,328          1,796  1,059
# 4          5-May  $14,419.00  20,306          5,055          1,659    985
# 5          6-May  $14,758.00  21,840          4,193          1,315    781
# 6          7-May  $14,581.00  22,282          3,206            901    537
# 7            NaN         NaN     NaN            NaN            NaN    NaN
# 8            NaN         NaN     NaN            NaN            NaN    NaN
# 9            Red       Costs  Visits  Registrations  Sites Created  Sales
# 10         1-May     $17,459  24,942          6,236          2,494  1,247
# 11         2-May     $17,293  24,704          6,176          2,470  1,235
# ...
